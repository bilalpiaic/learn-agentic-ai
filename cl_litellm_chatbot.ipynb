# %% [markdown]
# <a href="https://colab.research.google.com/github/bilalpiaic/learn-agentic-ai/blob/main/cl_litellm_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import os
#
# from dotenv import load_dotenv
#
# import chainlit as cl
#
# from litellm import completion
#
# import json
#
# # Load the environment variables from the .env file
# load_dotenv()
#
# gemini_api_key = os.getenv("GEMINI_API_KEY")
#
# # Check if the API key is present; if not, raise an error
# if not gemini_api_key:
#     raise ValueError("GEMINI_API_KEY is not set. Please ensure it is defined in your .env file.")
#
# @cl.on_chat_start
# async def start():
#     """Set up the chat session when a user connects."""
#     # Initialize an empty chat history in the session.
#     cl.user_session.set("chat_history", [])
#
#     await cl.Message(content="Welcome to the Panaversity AI Assistant! How can I help you today?").send()
#
# @cl.on_message
# async def main(message: cl.Message):
#     """Process incoming messages and generate responses."""
#     # Send a thinking message
#     msg = cl.Message(content="Thinking...")
#     await msg.send()
#
#     # Retrieve the chat history from the session.
#     history = cl.user_session.get("chat_history") or []
#
#     # Append the user's message to the history.
#     history.append({"role": "user", "content": message.content})
#
#
#     try:
#         # Get completion from LiteLLM
#         response = completion(
#             model="gemini/gemini-2.0-flash",
#             api_key=gemini_api_key,
#             messages=history
#         )
#
#         response_content = response.choices[0].message.content
#
#         # Update the thinking message with the actual response
#         msg.content = response_content
#         await msg.update()
#
#         # Append the assistant's response to the history.
#         history.append({"role": "assistant", "content": response_content})
#
#         # Update the session with the new history.
#         cl.user_session.set("chat_history", history)
#
#         # Optional: Log the interaction
#         print(f"User: {message.content}")
#         print(f"Assistant: {response_content}")
#
#     except Exception as e:
#         msg.content = f"Error: {str(e)}"
#         await msg.update()
#         print(f"Error: {str(e)}")
#
#
# # Right on it is not fully functioning because we are not
# # loading json file on on_chat_start
# @cl.on_chat_end
# async def on_chat_end():
#     # Retrieve the full chat history at the end of the session
#     history = cl.user_session.get("chat_history") or []
#     # Save the chat history to a file (or persist it elsewhere)
#     with open("chat_history.json", "w") as f:
#         json.dump(history, f, indent=2)
#     print("Chat history saved.")

# %%
# !pip install -Uq chainlit

# !pip install -Uq openai-agents  "openai-agents[litellm]"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 70.2 MB/s eta 0:00:00

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import chainlit as cl

from litellm import completion

import json

# %%
@cl.on_chat_start
async def start():
    """Set up the chat session when a user connects."""
    # Initialize an empty chat history in the session.
    cl.user_session.set("chat_history", [])

    await cl.Message(content="Welcome to the Panaversity AI Assistant! How can I help you today?").send()

@cl.on_message
async def main(message: cl.Message):
    """Process incoming messages and generate responses."""
    # Send a thinking message
    msg = cl.Message(content="Thinking...")
    await msg.send()

    # Retrieve the chat history from the session.
    history = cl.user_session.get("chat_history") or []

    # Append the user's message to the history.
    history.append({"role": "user", "content": message.content})


    try:
        # Get completion from LiteLLM
        response = completion(
            model="gemini/gemini-2.0-flash",
            api_key=GEMINI_API_KEY,
            messages=history
        )

        response_content = response.choices[0].message.content

        # Update the thinking message with the actual response
        msg.content = response_content
        await msg.update()

        # Append the assistant's response to the history.
        history.append({"role": "assistant", "content": response_content})

        # Update the session with the new history.
        cl.user_session.set("chat_history", history)

        # Optional: Log the interaction
        print(f"User: {message.content}")
        print(f"Assistant: {response_content}")

    except Exception as e:
        msg.content = f"Error: {str(e)}"
        await msg.update()
        print(f"Error: {str(e)}")


# Right on it is not fully functioning because we are not
# loading json file on on_chat_start
@cl.on_chat_end
async def on_chat_end():
    # Retrieve the full chat history at the end of the session
    history = cl.user_session.get("chat_history") or []
    # Save the chat history to a file (or persist it elsewhere)
    with open("chat_history.json", "w") as f:
        json.dump(history, f, indent=2)
    print("Chat history saved.")

# %%
# Cell 1: Install dependencies
# !pip install litellm python-dotenv

# Cell 2: Set up API key
from google.colab import userdata
import os

gemini_api_key = input("Enter your GEMINI_API_KEY: ")
os.environ['GEMINI_API_KEY'] = gemini_api_key

if not gemini_api_key:
    raise ValueError("GEMINI_API_KEY is not set.")

# Cell 3: Chatbot code
import os
import json
from litellm import completion

chat_history = []

def save_chat_history():
    with open("chat_history.json", "w") as f:
        json.dump(chat_history, f, indent=2)
    print("Chat history saved.")

def chat_loop():
    global chat_history
    print("Welcome to the Panaversity AI Assistant! Type 'exit' to quit.")

    while True:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            save_chat_history()
            break

        chat_history.append({"role": "user", "content": user_input})

        try:
            response = completion(
                model="gemini/gemini-2.0-flash",
                api_key=os.getenv("GEMINI_API_KEY"),
                messages=chat_history
            )
            response_content = response.choices[0].message.content
            print(f"Assistant: {response_content}")
            chat_history.append({"role": "assistant", "content": response_content})
            print(f"User: {user_input}")
            print(f"Assistant: {response_content}")
        except Exception as e:
            print(f"Error: {str(e)}")

chat_loop()

from google.colab import files
files.download("chat_history.json")
# Out:
# Requirement already satisfied: litellm in /usr/local/lib/python3.11/dist-packages (1.67.5)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm) (3.11.15)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from litellm) (8.1.8)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from litellm) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm) (8.6.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm) (4.23.0)
# Requirement already satisfied: openai>=1.68.2 in /usr/local/lib/python3.11/dist-packages (from litellm) (1.76.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from litellm) (2.11.4)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from litellm) (0.9.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm) (0.21.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.24.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.68.2->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.68.2->litellm) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.68.2->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>=1.68.2->litellm) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai>=1.68.2->litellm) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->litellm) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->litellm) (0.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.7.0->litellm) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.7.0->litellm) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm) (1.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers->litellm) (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (2.4.0)
# Enter your GEMINI_API_KEY: AIzaSyACWhE6WsZKUG_iiUKLkDyUEvTF7QjXW2Q
# Welcome to the Panaversity AI Assistant! Type 'exit' to quit.
# You: HI
# Assistant: Hi there! How can I help you today?
#
# User: HI
# Assistant: Hi there! How can I help you today?
#
# You: WHAT IS CURRENT SITUATION IN PAKISTAN
# Assistant: The current situation in Pakistan is complex and multifaceted, with significant challenges and ongoing developments across several key areas:
#
# **Political Situation:**
#
# *   **Instability and Polarization:** Pakistan has been experiencing political instability for some time. There's a deep divide between political parties, particularly the ruling coalition and the opposition led by Imran Khan's PTI (Pakistan Tehreek-e-Insaf).
# *   **Upcoming Elections:** General elections are expected to take place in the coming months. The preparations for these elections are underway, but there are concerns about fairness, transparency, and potential for unrest.
# *   **Crackdown on PTI:** The PTI party and its supporters have faced a crackdown, including arrests and restrictions on media coverage, leading to criticism from human rights organizations.
# *   **Civil-Military Relations:** The relationship between the civilian government and the military remains a significant factor in Pakistani politics. There are often perceptions of the military wielding considerable influence.
#
# **Economic Situation:**
#
# *   **Economic Crisis:** Pakistan is facing a severe economic crisis characterized by high inflation, a depreciating currency, dwindling foreign exchange reserves, and a large debt burden.
# *   **IMF Bailout:** Pakistan has secured a bailout package from the International Monetary Fund (IMF) to help stabilize the economy. However, the IMF conditions, which include fiscal austerity measures, are putting pressure on the government and the population.
# *   **Energy Crisis:** The country struggles with an energy crisis, including power outages and high electricity prices.
# *   **Impact on the Public:** The economic difficulties are impacting ordinary citizens through rising prices of essential goods, unemployment, and reduced purchasing power.
#
# **Security Situation:**
#
# *   **Terrorism and Insurgency:** Pakistan continues to face threats from various terrorist groups, particularly in the border regions with Afghanistan.
# *   **TTP Threat:** The Tehrik-i-Taliban Pakistan (TTP), also known as the Pakistani Taliban, has increased its attacks in recent years, posing a significant security challenge.
# *   **Balochistan Insurgency:** Separatist insurgents in Balochistan province continue to carry out attacks on security forces and infrastructure.
# *   **Regional Security:** The security situation in Afghanistan has implications for Pakistan, particularly concerning cross-border movements of militants and refugees.
#
# **Social Issues:**
#
# *   **Poverty and Inequality:** Poverty and income inequality remain significant challenges in Pakistan.
# *   **Education and Healthcare:** Access to quality education and healthcare is limited for many Pakistanis, particularly in rural areas.
# *   **Human Rights:** There are concerns about human rights in Pakistan, including freedom of expression, religious freedom, and the rights of minorities.
#
# **In Summary:**
#
# Pakistan is navigating a difficult period with complex political, economic, and security challenges. The upcoming elections will be a crucial moment for the country. The economic crisis is severely impacting the population, and the security situation remains fragile. The country's ability to address these challenges will have significant implications for its future stability and development.
#
# **Disclaimer:** The situation in Pakistan is constantly evolving. This information is based on currently available news and analysis, and the situation may have changed since my last update. For the very latest developments, refer to credible news sources.
#
# User: WHAT IS CURRENT SITUATION IN PAKISTAN
# Assistant: The current situation in Pakistan is complex and multifaceted, with significant challenges and ongoing developments across several key areas:
#
# **Political Situation:**
#
# *   **Instability and Polarization:** Pakistan has been experiencing political instability for some time. There's a deep divide between political parties, particularly the ruling coalition and the opposition led by Imran Khan's PTI (Pakistan Tehreek-e-Insaf).
# *   **Upcoming Elections:** General elections are expected to take place in the coming months. The preparations for these elections are underway, but there are concerns about fairness, transparency, and potential for unrest.
# *   **Crackdown on PTI:** The PTI party and its supporters have faced a crackdown, including arrests and restrictions on media coverage, leading to criticism from human rights organizations.
# *   **Civil-Military Relations:** The relationship between the civilian government and the military remains a significant factor in Pakistani politics. There are often perceptions of the military wielding considerable influence.
#
# **Economic Situation:**
#
# *   **Economic Crisis:** Pakistan is facing a severe economic crisis characterized by high inflation, a depreciating currency, dwindling foreign exchange reserves, and a large debt burden.
# *   **IMF Bailout:** Pakistan has secured a bailout package from the International Monetary Fund (IMF) to help stabilize the economy. However, the IMF conditions, which include fiscal austerity measures, are putting pressure on the government and the population.
# *   **Energy Crisis:** The country struggles with an energy crisis, including power outages and high electricity prices.
# *   **Impact on the Public:** The economic difficulties are impacting ordinary citizens through rising prices of essential goods, unemployment, and reduced purchasing power.
#
# **Security Situation:**
#
# *   **Terrorism and Insurgency:** Pakistan continues to face threats from various terrorist groups, particularly in the border regions with Afghanistan.
# *   **TTP Threat:** The Tehrik-i-Taliban Pakistan (TTP), also known as the Pakistani Taliban, has increased its attacks in recent years, posing a significant security challenge.
# *   **Balochistan Insurgency:** Separatist insurgents in Balochistan province continue to carry out attacks on security forces and infrastructure.
# *   **Regional Security:** The security situation in Afghanistan has implications for Pakistan, particularly concerning cross-border movements of militants and refugees.
#
# **Social Issues:**
#
# *   **Poverty and Inequality:** Poverty and income inequality remain significant challenges in Pakistan.
# *   **Education and Healthcare:** Access to quality education and healthcare is limited for many Pakistanis, particularly in rural areas.
# *   **Human Rights:** There are concerns about human rights in Pakistan, including freedom of expression, religious freedom, and the rights of minorities.
#
# **In Summary:**
#
# Pakistan is navigating a difficult period with complex political, economic, and security challenges. The upcoming elections will be a crucial moment for the country. The economic crisis is severely impacting the population, and the security situation remains fragile. The country's ability to address these challenges will have significant implications for its future stability and development.
#
# **Disclaimer:** The situation in Pakistan is constantly evolving. This information is based on currently available news and analysis, and the situation may have changed since my last update. For the very latest developments, refer to credible news sources.
#
# You: WHAT IS AIR FIGHTING STRENGTH OF PAKISTAN
# Assistant: Pakistan's Air Force (PAF) is generally considered to be a capable and well-equipped air force. Assessing its fighting strength is complex, but here's a breakdown of key aspects:
#
# **Aircraft Inventory (Estimates - Numbers Can Vary):**
#
# *   **Fighter Aircraft:** This is the core of the PAF's fighting strength.  Key types include:
#     *   **F-16 Fighting Falcon:** Around 75-85 of various blocks (A/B and C/D). These are highly capable multirole fighters and a mainstay of the PAF. Their numbers and capabilities are often a focus in discussions about PAF strength.
#     *   **JF-17 Thunder:** This is a co-produced (with China) multirole fighter.  The PAF has a significant number (around 120-140+) and is continuously adding newer blocks (Block III). The JF-17 is becoming increasingly important to the PAF.
#     *   **Mirage III/V:** Older aircraft, but still a part of the fleet, though their role is likely more limited these days. Numbers are decreasing due to attrition and obsolescence.
#     *   **J-10C:** Relatively new addition from China. Highly capable, advanced fighter. Numbers relatively small so far (around 6-12).
# *   **Ground Attack:**
#     *   Some fighters like the F-16 and JF-17 also have ground attack capabilities.
# *   **Airborne Early Warning and Control (AEW&C):**
#     *   Pakistan operates Saab 2000 Erieye AEW&C aircraft, which provide crucial airspace surveillance and command and control capabilities. They also have Chinese ZDK-03 AEW&C aircraft.
# *   **Transport Aircraft:** A mix of Chinese, European, and American transport aircraft for troop and cargo transport.
# *   **Helicopters:** A variety of helicopters for transport, search and rescue, and attack roles.
# *   **Training Aircraft:** Aircraft for pilot training.
#
# **Key Strengths:**
#
# *   **Well-Trained Pilots and Personnel:** The PAF has a reputation for having well-trained and professional pilots and ground crew. Their training programs are rigorous and often incorporate lessons learned from exercises with other air forces.
# *   **Modern Equipment:** While some of the PAF's aircraft are older, they have been upgraded. The addition of the JF-17 and J-10C have significantly improved its capabilities.
# *   **Air-to-Air Refueling:** The PAF has air-to-air refueling capabilities, extending the range and endurance of its fighter aircraft.
# *   **Integrated Air Defence System:** Pakistan has invested in an integrated air defense system, including radar systems, surface-to-air missiles, and command and control infrastructure.
# *   **Strategic Partnerships:** Close ties with China have been vital for acquiring advanced military technology.
#
# **Weaknesses and Challenges:**
#
# *   **Dependence on Foreign Suppliers:** Pakistan relies on foreign suppliers (China, US, others) for its military equipment. This can create vulnerabilities in terms of spare parts, maintenance, and political considerations.
# *   **Economic Constraints:** Pakistan's economic challenges can limit its ability to procure new equipment and upgrade existing systems.
# *   **Maintaining Older Aircraft:** Keeping older aircraft like the Mirage III/V operational can be costly and challenging.
# *   **Quantity vs. Quality:** While the PAF has a decent number of aircraft, the Indian Air Force (IAF) has a significantly larger fleet. Pakistan relies on quality, training, and tactics to offset the numerical disadvantage.
#
# **Comparison with Regional Air Forces (Specifically India):**
#
# *   The Indian Air Force (IAF) is significantly larger than the PAF in terms of the total number of aircraft.
# *   The IAF also operates a wider range of advanced fighter aircraft, including Su-30MKI, Rafale, and others.
# *   However, the PAF has some advantages in certain areas, such as the JF-17's cost-effectiveness and the J-10C's advanced capabilities.
#
# **Overall Assessment:**
#
# The PAF is a capable air force that plays a crucial role in Pakistan's defense. It has invested in modern equipment, training, and integrated air defense systems. While it faces challenges related to economic constraints and reliance on foreign suppliers, it remains a formidable force in the region. However, the IAF is significantly larger and possesses more advanced technology overall. The PAF relies on its skilled pilots, tactics, and strategic partnerships to maintain a credible deterrent.
#
# It's important to note that assessing military strength is not just about numbers. Factors like pilot training, maintenance, electronic warfare capabilities, and overall strategy are also critical.
#
# **Important Note:** Information about military capabilities is often classified or subject to varying estimates. The information provided here is based on publicly available sources and represents a general overview. Specific numbers and capabilities may vary.
#
# User: WHAT IS AIR FIGHTING STRENGTH OF PAKISTAN
# Assistant: Pakistan's Air Force (PAF) is generally considered to be a capable and well-equipped air force. Assessing its fighting strength is complex, but here's a breakdown of key aspects:
#
# **Aircraft Inventory (Estimates - Numbers Can Vary):**
#
# *   **Fighter Aircraft:** This is the core of the PAF's fighting strength.  Key types include:
#     *   **F-16 Fighting Falcon:** Around 75-85 of various blocks (A/B and C/D). These are highly capable multirole fighters and a mainstay of the PAF. Their numbers and capabilities are often a focus in discussions about PAF strength.
#     *   **JF-17 Thunder:** This is a co-produced (with China) multirole fighter.  The PAF has a significant number (around 120-140+) and is continuously adding newer blocks (Block III). The JF-17 is becoming increasingly important to the PAF.
#     *   **Mirage III/V:** Older aircraft, but still a part of the fleet, though their role is likely more limited these days. Numbers are decreasing due to attrition and obsolescence.
#     *   **J-10C:** Relatively new addition from China. Highly capable, advanced fighter. Numbers relatively small so far (around 6-12).
# *   **Ground Attack:**
#     *   Some fighters like the F-16 and JF-17 also have ground attack capabilities.
# *   **Airborne Early Warning and Control (AEW&C):**
#     *   Pakistan operates Saab 2000 Erieye AEW&C aircraft, which provide crucial airspace surveillance and command and control capabilities. They also have Chinese ZDK-03 AEW&C aircraft.
# *   **Transport Aircraft:** A mix of Chinese, European, and American transport aircraft for troop and cargo transport.
# *   **Helicopters:** A variety of helicopters for transport, search and rescue, and attack roles.
# *   **Training Aircraft:** Aircraft for pilot training.
#
# **Key Strengths:**
#
# *   **Well-Trained Pilots and Personnel:** The PAF has a reputation for having well-trained and professional pilots and ground crew. Their training programs are rigorous and often incorporate lessons learned from exercises with other air forces.
# *   **Modern Equipment:** While some of the PAF's aircraft are older, they have been upgraded. The addition of the JF-17 and J-10C have significantly improved its capabilities.
# *   **Air-to-Air Refueling:** The PAF has air-to-air refueling capabilities, extending the range and endurance of its fighter aircraft.
# *   **Integrated Air Defence System:** Pakistan has invested in an integrated air defense system, including radar systems, surface-to-air missiles, and command and control infrastructure.
# *   **Strategic Partnerships:** Close ties with China have been vital for acquiring advanced military technology.
#
# **Weaknesses and Challenges:**
#
# *   **Dependence on Foreign Suppliers:** Pakistan relies on foreign suppliers (China, US, others) for its military equipment. This can create vulnerabilities in terms of spare parts, maintenance, and political considerations.
# *   **Economic Constraints:** Pakistan's economic challenges can limit its ability to procure new equipment and upgrade existing systems.
# *   **Maintaining Older Aircraft:** Keeping older aircraft like the Mirage III/V operational can be costly and challenging.
# *   **Quantity vs. Quality:** While the PAF has a decent number of aircraft, the Indian Air Force (IAF) has a significantly larger fleet. Pakistan relies on quality, training, and tactics to offset the numerical disadvantage.
#
# **Comparison with Regional Air Forces (Specifically India):**
#
# *   The Indian Air Force (IAF) is significantly larger than the PAF in terms of the total number of aircraft.
# *   The IAF also operates a wider range of advanced fighter aircraft, including Su-30MKI, Rafale, and others.
# *   However, the PAF has some advantages in certain areas, such as the JF-17's cost-effectiveness and the J-10C's advanced capabilities.
#
# **Overall Assessment:**
#
# The PAF is a capable air force that plays a crucial role in Pakistan's defense. It has invested in modern equipment, training, and integrated air defense systems. While it faces challenges related to economic constraints and reliance on foreign suppliers, it remains a formidable force in the region. However, the IAF is significantly larger and possesses more advanced technology overall. The PAF relies on its skilled pilots, tactics, and strategic partnerships to maintain a credible deterrent.
#
# It's important to note that assessing military strength is not just about numbers. Factors like pilot training, maintenance, electronic warfare capabilities, and overall strategy are also critical.
#
# **Important Note:** Information about military capabilities is often classified or subject to varying estimates. The information provided here is based on publicly available sources and represents a general overview. Specific numbers and capabilities may vary.
#
# You: EXIT
# Chat history saved.
